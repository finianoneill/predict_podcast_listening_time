# %% [markdown]
# # Model Inference Notebook
#
# * Author: Finian O'Neill
# * Purpose: Load in the test data and then make predictions using the best model from model training.

# %% [markdown]
# ### Setup

# %%
import pandas as pd
import joblib
from sklearn.ensemble import RandomForestRegressor
import json

# %%
def load_best_model(saved_paths, results, task='classification', metric=None):
    """
    Load the best model based on evaluation metrics
    
    Parameters:
    -----------
    saved_paths : list
        List of saved model file paths
    results : dict
        Dictionary containing evaluation metrics for each model
    task : str, default='classification'
        Type of task: 'classification' or 'regression'
    metric : str, optional
        Specific metric to use for model selection
        
    Returns:
    --------
    object
        The best trained model
    """
    if metric is None:
        metric = 'accuracy' if task == 'classification' else 'rmse'
    
    model_names = [path.split('_')[1].split('.')[0] for path in saved_paths]
    
    if task == 'classification':
        scores = [results[name][metric] for name in model_names]
        best_idx = np.argmax(scores)
    else:  # Regression - lower RMSE is better
        scores = [results[name][metric] for name in model_names]
        best_idx = np.argmin(scores)
    
    best_model_path = saved_paths[best_idx]
    best_model = joblib.load(best_model_path)
    
    return best_model

# %% [markdown]
# ### Data Load

# %%
# load in the test dataset
test_df = pd.read_csv('data/test.csv')
test_df.head()
# Out:
#        id         Podcast_Name Episode_Title  Episode_Length_minutes  \
# 0  750000  Educational Nuggets    Episode 73                   78.96
# 1  750001          Sound Waves    Episode 23                   27.87
# 2  750002        Joke Junction    Episode 11                   69.10
# 3  750003        Comedy Corner    Episode 73                  115.39
# 4  750004         Life Lessons    Episode 50                   72.32
#
#        Genre  Host_Popularity_percentage Publication_Day Publication_Time  \
# 0  Education                       38.11        Saturday          Evening
# 1      Music                       71.29          Sunday          Morning
# 2     Comedy                       67.89          Friday          Evening
# 3     Comedy                       23.40          Sunday          Morning
# 4  Lifestyle                       58.10       Wednesday          Morning
#
#    Guest_Popularity_percentage  Number_of_Ads Episode_Sentiment
# 0                        53.33            1.0           Neutral
# 1                          NaN            0.0           Neutral
# 2                        97.51            0.0          Positive
# 3                        51.75            2.0          Positive
# 4                        11.30            2.0           Neutral

# %%
# load in the saved results
with open('artifacts/tree_model_results.json', 'r') as file:
    results = json.load(file)
file.close()

# %%
# construct the saved paths
saved_paths = {
    'random_forest': 'artifacts/models/model_random_forest.pkl',
    'xgboost': 'artifacts/models/model_xgboost.pkl',
    'lightgbm': 'artifacts/models/model_lightgbm.pkl',
    'catboost': 'artifacts/models/model_catboost.pkl'
}

# %%
# load in the podcast name cluster map
with open('artifacts/podcast_name_cluster_map.json', 'r') as file:
    podcast_name_cluster_map = json.load(file)
file.close()

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# #### 1) Podcast_Name

# %%
# create copy of original dataframe to encode
test_encoded_df = test_df.copy()

# %%
# create the 'Podcast_Name_clustered' column
test_encoded_df['Podcast_Name_clustered'] = test_encoded_df['Podcast_Name'].map(podcast_name_cluster_map).fillna('unknown')
test_encoded_df.head()
# Out:
#        id         Podcast_Name Episode_Title  Episode_Length_minutes  \
# 0  750000  Educational Nuggets    Episode 73                   78.96
# 1  750001          Sound Waves    Episode 23                   27.87
# 2  750002        Joke Junction    Episode 11                   69.10
# 3  750003        Comedy Corner    Episode 73                  115.39
# 4  750004         Life Lessons    Episode 50                   72.32
#
#        Genre  Host_Popularity_percentage Publication_Day Publication_Time  \
# 0  Education                       38.11        Saturday          Evening
# 1      Music                       71.29          Sunday          Morning
# 2     Comedy                       67.89          Friday          Evening
# 3     Comedy                       23.40          Sunday          Morning
# 4  Lifestyle                       58.10       Wednesday          Morning
#
#    Guest_Popularity_percentage  Number_of_Ads Episode_Sentiment  \
# 0                        53.33            1.0           Neutral
# 1                          NaN            0.0           Neutral
# 2                        97.51            0.0          Positive
# 3                        51.75            2.0          Positive
# 4                        11.30            2.0           Neutral
#
#     Podcast_Name_clustered
# 0    Tech Trends_cluster_2
# 1    Tech Trends_cluster_2
# 2     Tech Talks_cluster_0
# 3     Tech Talks_cluster_0
# 4  Sports Weekly_cluster_1

# %%
# now one hot encode the clustered values
test_encoded_df = pd.get_dummies(test_encoded_df, columns=['Podcast_Name_clustered'])
test_encoded_df.head()
# Out:
#        id         Podcast_Name Episode_Title  Episode_Length_minutes  \
# 0  750000  Educational Nuggets    Episode 73                   78.96
# 1  750001          Sound Waves    Episode 23                   27.87
# 2  750002        Joke Junction    Episode 11                   69.10
# 3  750003        Comedy Corner    Episode 73                  115.39
# 4  750004         Life Lessons    Episode 50                   72.32
#
#        Genre  Host_Popularity_percentage Publication_Day Publication_Time  \
# 0  Education                       38.11        Saturday          Evening
# 1      Music                       71.29          Sunday          Morning
# 2     Comedy                       67.89          Friday          Evening
# 3     Comedy                       23.40          Sunday          Morning
# 4  Lifestyle                       58.10       Wednesday          Morning
#
#    Guest_Popularity_percentage  Number_of_Ads Episode_Sentiment  \
# 0                        53.33            1.0           Neutral
# 1                          NaN            0.0           Neutral
# 2                        97.51            0.0          Positive
# 3                        51.75            2.0          Positive
# 4                        11.30            2.0           Neutral
#
#    Podcast_Name_clustered_Sports Weekly_cluster_1  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                            True
#
#    Podcast_Name_clustered_Tech Talks_cluster_0  \
# 0                                        False
# 1                                        False
# 2                                         True
# 3                                         True
# 4                                        False
#
#    Podcast_Name_clustered_Tech Trends_cluster_2
# 0                                          True
# 1                                          True
# 2                                         False
# 3                                         False
# 4                                         False

# %%
# drop the no longer needed 'Podcast_Name' column
test_encoded_df = test_encoded_df.drop(columns=['Podcast_Name'])
test_encoded_df.head()
# Out:
#        id Episode_Title  Episode_Length_minutes      Genre  \
# 0  750000    Episode 73                   78.96  Education
# 1  750001    Episode 23                   27.87      Music
# 2  750002    Episode 11                   69.10     Comedy
# 3  750003    Episode 73                  115.39     Comedy
# 4  750004    Episode 50                   72.32  Lifestyle
#
#    Host_Popularity_percentage Publication_Day Publication_Time  \
# 0                       38.11        Saturday          Evening
# 1                       71.29          Sunday          Morning
# 2                       67.89          Friday          Evening
# 3                       23.40          Sunday          Morning
# 4                       58.10       Wednesday          Morning
#
#    Guest_Popularity_percentage  Number_of_Ads Episode_Sentiment  \
# 0                        53.33            1.0           Neutral
# 1                          NaN            0.0           Neutral
# 2                        97.51            0.0          Positive
# 3                        51.75            2.0          Positive
# 4                        11.30            2.0           Neutral
#
#    Podcast_Name_clustered_Sports Weekly_cluster_1  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                            True
#
#    Podcast_Name_clustered_Tech Talks_cluster_0  \
# 0                                        False
# 1                                        False
# 2                                         True
# 3                                         True
# 4                                        False
#
#    Podcast_Name_clustered_Tech Trends_cluster_2
# 0                                          True
# 1                                          True
# 2                                         False
# 3                                         False
# 4                                         False

# %% [markdown]
# #### 2) Episode_Title

# %%
# from this list, it seems like episodes range from 1 to 100. I will simplify assumptions and just bin
# as the following for each podcast
# early --> 1 - 33
# mid --> 34 - 66
# late --> 67 - 100
early_list = ['Episode {counter}'.format(counter=n + 1) for n in range(100) if n + 1 <= 33]
mid_list = ['Episode {counter}'.format(counter=n + 1) for n in range(100) if (n + 1 > 33) and (n + 1 <= 66)]
late_list = ['Episode {counter}'.format(counter=n + 1) for n in range(100) if (n + 1 > 66) and (n + 1 <= 100)]

# create episode dict
episode_map = {}
# add early entries
for i in range(len(early_list)):
    episode_map[early_list[i]] = 'early'
# add mid entries
for j in range(len(mid_list)):
    episode_map[mid_list[j]] = 'mid'
# add late entries
for k in range(len(late_list)):
    episode_map[late_list[k]] = 'late'
    
print(episode_map)
# Out:
# {'Episode 1': 'early', 'Episode 2': 'early', 'Episode 3': 'early', 'Episode 4': 'early', 'Episode 5': 'early', 'Episode 6': 'early', 'Episode 7': 'early', 'Episode 8': 'early', 'Episode 9': 'early', 'Episode 10': 'early', 'Episode 11': 'early', 'Episode 12': 'early', 'Episode 13': 'early', 'Episode 14': 'early', 'Episode 15': 'early', 'Episode 16': 'early', 'Episode 17': 'early', 'Episode 18': 'early', 'Episode 19': 'early', 'Episode 20': 'early', 'Episode 21': 'early', 'Episode 22': 'early', 'Episode 23': 'early', 'Episode 24': 'early', 'Episode 25': 'early', 'Episode 26': 'early', 'Episode 27': 'early', 'Episode 28': 'early', 'Episode 29': 'early', 'Episode 30': 'early', 'Episode 31': 'early', 'Episode 32': 'early', 'Episode 33': 'early', 'Episode 34': 'mid', 'Episode 35': 'mid', 'Episode 36': 'mid', 'Episode 37': 'mid', 'Episode 38': 'mid', 'Episode 39': 'mid', 'Episode 40': 'mid', 'Episode 41': 'mid', 'Episode 42': 'mid', 'Episode 43': 'mid', 'Episode 44': 'mid', 'Episode 45': 'mid', 'Episode 46': 'mid', 'Episode 47': 'mid', 'Episode 48': 'mid', 'Episode 49': 'mid', 'Episode 50': 'mid', 'Episode 51': 'mid', 'Episode 52': 'mid', 'Episode 53': 'mid', 'Episode 54': 'mid', 'Episode 55': 'mid', 'Episode 56': 'mid', 'Episode 57': 'mid', 'Episode 58': 'mid', 'Episode 59': 'mid', 'Episode 60': 'mid', 'Episode 61': 'mid', 'Episode 62': 'mid', 'Episode 63': 'mid', 'Episode 64': 'mid', 'Episode 65': 'mid', 'Episode 66': 'mid', 'Episode 67': 'late', 'Episode 68': 'late', 'Episode 69': 'late', 'Episode 70': 'late', 'Episode 71': 'late', 'Episode 72': 'late', 'Episode 73': 'late', 'Episode 74': 'late', 'Episode 75': 'late', 'Episode 76': 'late', 'Episode 77': 'late', 'Episode 78': 'late', 'Episode 79': 'late', 'Episode 80': 'late', 'Episode 81': 'late', 'Episode 82': 'late', 'Episode 83': 'late', 'Episode 84': 'late', 'Episode 85': 'late', 'Episode 86': 'late', 'Episode 87': 'late', 'Episode 88': 'late', 'Episode 89': 'late', 'Episode 90': 'late', 'Episode 91': 'late', 'Episode 92': 'late', 'Episode 93': 'late', 'Episode 94': 'late', 'Episode 95': 'late', 'Episode 96': 'late', 'Episode 97': 'late', 'Episode 98': 'late', 'Episode 99': 'late', 'Episode 100': 'late'}

# %%
# bin the actual 'Episode_Title' column
test_encoded_df['Episode_Title_binned'] = test_encoded_df['Episode_Title'].map(episode_map).fillna('unknown')
test_encoded_df.head()
# Out:
#        id Episode_Title  Episode_Length_minutes      Genre  \
# 0  750000    Episode 73                   78.96  Education
# 1  750001    Episode 23                   27.87      Music
# 2  750002    Episode 11                   69.10     Comedy
# 3  750003    Episode 73                  115.39     Comedy
# 4  750004    Episode 50                   72.32  Lifestyle
#
#    Host_Popularity_percentage Publication_Day Publication_Time  \
# 0                       38.11        Saturday          Evening
# 1                       71.29          Sunday          Morning
# 2                       67.89          Friday          Evening
# 3                       23.40          Sunday          Morning
# 4                       58.10       Wednesday          Morning
#
#    Guest_Popularity_percentage  Number_of_Ads Episode_Sentiment  \
# 0                        53.33            1.0           Neutral
# 1                          NaN            0.0           Neutral
# 2                        97.51            0.0          Positive
# 3                        51.75            2.0          Positive
# 4                        11.30            2.0           Neutral
#
#    Podcast_Name_clustered_Sports Weekly_cluster_1  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                            True
#
#    Podcast_Name_clustered_Tech Talks_cluster_0  \
# 0                                        False
# 1                                        False
# 2                                         True
# 3                                         True
# 4                                        False
#
#    Podcast_Name_clustered_Tech Trends_cluster_2 Episode_Title_binned
# 0                                          True                 late
# 1                                          True                early
# 2                                         False                early
# 3                                         False                 late
# 4                                         False                  mid

# %%
# now one hot encode the binned values
test_encoded_df = pd.get_dummies(test_encoded_df, columns=['Episode_Title_binned'])
test_encoded_df.head()
# Out:
#        id Episode_Title  Episode_Length_minutes      Genre  \
# 0  750000    Episode 73                   78.96  Education
# 1  750001    Episode 23                   27.87      Music
# 2  750002    Episode 11                   69.10     Comedy
# 3  750003    Episode 73                  115.39     Comedy
# 4  750004    Episode 50                   72.32  Lifestyle
#
#    Host_Popularity_percentage Publication_Day Publication_Time  \
# 0                       38.11        Saturday          Evening
# 1                       71.29          Sunday          Morning
# 2                       67.89          Friday          Evening
# 3                       23.40          Sunday          Morning
# 4                       58.10       Wednesday          Morning
#
#    Guest_Popularity_percentage  Number_of_Ads Episode_Sentiment  \
# 0                        53.33            1.0           Neutral
# 1                          NaN            0.0           Neutral
# 2                        97.51            0.0          Positive
# 3                        51.75            2.0          Positive
# 4                        11.30            2.0           Neutral
#
#    Podcast_Name_clustered_Sports Weekly_cluster_1  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                            True
#
#    Podcast_Name_clustered_Tech Talks_cluster_0  \
# 0                                        False
# 1                                        False
# 2                                         True
# 3                                         True
# 4                                        False
#
#    Podcast_Name_clustered_Tech Trends_cluster_2  Episode_Title_binned_early  \
# 0                                          True                       False
# 1                                          True                        True
# 2                                         False                        True
# 3                                         False                       False
# 4                                         False                       False
#
#    Episode_Title_binned_late  Episode_Title_binned_mid
# 0                       True                     False
# 1                      False                     False
# 2                      False                     False
# 3                       True                     False
# 4                      False                      True

# %%
# drop the no longer needed 'Episode_Title' column
test_encoded_df = test_encoded_df.drop(columns=['Episode_Title'])
test_encoded_df.head()
# Out:
#        id  Episode_Length_minutes      Genre  Host_Popularity_percentage  \
# 0  750000                   78.96  Education                       38.11
# 1  750001                   27.87      Music                       71.29
# 2  750002                   69.10     Comedy                       67.89
# 3  750003                  115.39     Comedy                       23.40
# 4  750004                   72.32  Lifestyle                       58.10
#
#   Publication_Day Publication_Time  Guest_Popularity_percentage  \
# 0        Saturday          Evening                        53.33
# 1          Sunday          Morning                          NaN
# 2          Friday          Evening                        97.51
# 3          Sunday          Morning                        51.75
# 4       Wednesday          Morning                        11.30
#
#    Number_of_Ads Episode_Sentiment  \
# 0            1.0           Neutral
# 1            0.0           Neutral
# 2            0.0          Positive
# 3            2.0          Positive
# 4            2.0           Neutral
#
#    Podcast_Name_clustered_Sports Weekly_cluster_1  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                            True
#
#    Podcast_Name_clustered_Tech Talks_cluster_0  \
# 0                                        False
# 1                                        False
# 2                                         True
# 3                                         True
# 4                                        False
#
#    Podcast_Name_clustered_Tech Trends_cluster_2  Episode_Title_binned_early  \
# 0                                          True                       False
# 1                                          True                        True
# 2                                         False                        True
# 3                                         False                       False
# 4                                         False                       False
#
#    Episode_Title_binned_late  Episode_Title_binned_mid
# 0                       True                     False
# 1                      False                     False
# 2                      False                     False
# 3                       True                     False
# 4                      False                      True

# %% [markdown]
# #### 3) Genre

# %%
# one-hot encode the Genre since there are only 10 categories
test_encoded_df = pd.get_dummies(test_encoded_df, columns=['Genre'])
test_encoded_df.head()
# Out:
#        id  Episode_Length_minutes  Host_Popularity_percentage Publication_Day  \
# 0  750000                   78.96                       38.11        Saturday
# 1  750001                   27.87                       71.29          Sunday
# 2  750002                   69.10                       67.89          Friday
# 3  750003                  115.39                       23.40          Sunday
# 4  750004                   72.32                       58.10       Wednesday
#
#   Publication_Time  Guest_Popularity_percentage  Number_of_Ads  \
# 0          Evening                        53.33            1.0
# 1          Morning                          NaN            0.0
# 2          Evening                        97.51            0.0
# 3          Morning                        51.75            2.0
# 4          Morning                        11.30            2.0
#
#   Episode_Sentiment  Podcast_Name_clustered_Sports Weekly_cluster_1  \
# 0           Neutral                                           False
# 1           Neutral                                           False
# 2          Positive                                           False
# 3          Positive                                           False
# 4           Neutral                                            True
#
#    Podcast_Name_clustered_Tech Talks_cluster_0  ...  Genre_Business  \
# 0                                        False  ...           False
# 1                                        False  ...           False
# 2                                         True  ...           False
# 3                                         True  ...           False
# 4                                        False  ...           False
#
#    Genre_Comedy  Genre_Education  Genre_Health  Genre_Lifestyle  Genre_Music  \
# 0         False             True         False            False        False
# 1         False            False         False            False         True
# 2          True            False         False            False        False
# 3          True            False         False            False        False
# 4         False            False         False             True        False
#
#    Genre_News  Genre_Sports  Genre_Technology  Genre_True Crime
# 0       False         False             False             False
# 1       False         False             False             False
# 2       False         False             False             False
# 3       False         False             False             False
# 4       False         False             False             False
#
# [5 rows x 24 columns]

# %% [markdown]
# #### 4) Publication_Day

# %%
# one-hot encode the Publication_Day since there are only 7 categories
test_encoded_df = pd.get_dummies(test_encoded_df, columns=['Publication_Day'])
test_encoded_df.head()
# Out:
#        id  Episode_Length_minutes  Host_Popularity_percentage  \
# 0  750000                   78.96                       38.11
# 1  750001                   27.87                       71.29
# 2  750002                   69.10                       67.89
# 3  750003                  115.39                       23.40
# 4  750004                   72.32                       58.10
#
#   Publication_Time  Guest_Popularity_percentage  Number_of_Ads  \
# 0          Evening                        53.33            1.0
# 1          Morning                          NaN            0.0
# 2          Evening                        97.51            0.0
# 3          Morning                        51.75            2.0
# 4          Morning                        11.30            2.0
#
#   Episode_Sentiment  Podcast_Name_clustered_Sports Weekly_cluster_1  \
# 0           Neutral                                           False
# 1           Neutral                                           False
# 2          Positive                                           False
# 3          Positive                                           False
# 4           Neutral                                            True
#
#    Podcast_Name_clustered_Tech Talks_cluster_0  \
# 0                                        False
# 1                                        False
# 2                                         True
# 3                                         True
# 4                                        False
#
#    Podcast_Name_clustered_Tech Trends_cluster_2  ...  Genre_Sports  \
# 0                                          True  ...         False
# 1                                          True  ...         False
# 2                                         False  ...         False
# 3                                         False  ...         False
# 4                                         False  ...         False
#
#    Genre_Technology  Genre_True Crime  Publication_Day_Friday  \
# 0             False             False                   False
# 1             False             False                   False
# 2             False             False                    True
# 3             False             False                   False
# 4             False             False                   False
#
#    Publication_Day_Monday  Publication_Day_Saturday  Publication_Day_Sunday  \
# 0                   False                      True                   False
# 1                   False                     False                    True
# 2                   False                     False                   False
# 3                   False                     False                    True
# 4                   False                     False                   False
#
#    Publication_Day_Thursday  Publication_Day_Tuesday  \
# 0                     False                    False
# 1                     False                    False
# 2                     False                    False
# 3                     False                    False
# 4                     False                    False
#
#    Publication_Day_Wednesday
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                       True
#
# [5 rows x 30 columns]

# %% [markdown]
# #### 5) Publication_Time

# %%
# one-hot encode the Publication_Time since there are only 4 categories
test_encoded_df = pd.get_dummies(test_encoded_df, columns=['Publication_Time'])
test_encoded_df.head()
# Out:
#        id  Episode_Length_minutes  Host_Popularity_percentage  \
# 0  750000                   78.96                       38.11
# 1  750001                   27.87                       71.29
# 2  750002                   69.10                       67.89
# 3  750003                  115.39                       23.40
# 4  750004                   72.32                       58.10
#
#    Guest_Popularity_percentage  Number_of_Ads Episode_Sentiment  \
# 0                        53.33            1.0           Neutral
# 1                          NaN            0.0           Neutral
# 2                        97.51            0.0          Positive
# 3                        51.75            2.0          Positive
# 4                        11.30            2.0           Neutral
#
#    Podcast_Name_clustered_Sports Weekly_cluster_1  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                            True
#
#    Podcast_Name_clustered_Tech Talks_cluster_0  \
# 0                                        False
# 1                                        False
# 2                                         True
# 3                                         True
# 4                                        False
#
#    Podcast_Name_clustered_Tech Trends_cluster_2  Episode_Title_binned_early  \
# 0                                          True                       False
# 1                                          True                        True
# 2                                         False                        True
# 3                                         False                       False
# 4                                         False                       False
#
#    ...  Publication_Day_Monday  Publication_Day_Saturday  \
# 0  ...                   False                      True
# 1  ...                   False                     False
# 2  ...                   False                     False
# 3  ...                   False                     False
# 4  ...                   False                     False
#
#    Publication_Day_Sunday  Publication_Day_Thursday  Publication_Day_Tuesday  \
# 0                   False                     False                    False
# 1                    True                     False                    False
# 2                   False                     False                    False
# 3                    True                     False                    False
# 4                   False                     False                    False
#
#    Publication_Day_Wednesday  Publication_Time_Afternoon  \
# 0                      False                       False
# 1                      False                       False
# 2                      False                       False
# 3                      False                       False
# 4                       True                       False
#
#    Publication_Time_Evening  Publication_Time_Morning  Publication_Time_Night
# 0                      True                     False                   False
# 1                     False                      True                   False
# 2                      True                     False                   False
# 3                     False                      True                   False
# 4                     False                      True                   False
#
# [5 rows x 33 columns]

# %% [markdown]
# #### 6) Episode_Sentiment

# %%
# for the sentiment map to values to ascribe ordinality
episode_sentiment_map = {
    'Negative': -1,
    'Neutral': 0,
    'Positive': 1
}

test_encoded_df['Episode_Sentiment_mapped'] = test_encoded_df['Episode_Sentiment'].map(episode_sentiment_map)
test_encoded_df.head()
# Out:
#        id  Episode_Length_minutes  Host_Popularity_percentage  \
# 0  750000                   78.96                       38.11
# 1  750001                   27.87                       71.29
# 2  750002                   69.10                       67.89
# 3  750003                  115.39                       23.40
# 4  750004                   72.32                       58.10
#
#    Guest_Popularity_percentage  Number_of_Ads Episode_Sentiment  \
# 0                        53.33            1.0           Neutral
# 1                          NaN            0.0           Neutral
# 2                        97.51            0.0          Positive
# 3                        51.75            2.0          Positive
# 4                        11.30            2.0           Neutral
#
#    Podcast_Name_clustered_Sports Weekly_cluster_1  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                            True
#
#    Podcast_Name_clustered_Tech Talks_cluster_0  \
# 0                                        False
# 1                                        False
# 2                                         True
# 3                                         True
# 4                                        False
#
#    Podcast_Name_clustered_Tech Trends_cluster_2  Episode_Title_binned_early  \
# 0                                          True                       False
# 1                                          True                        True
# 2                                         False                        True
# 3                                         False                       False
# 4                                         False                       False
#
#    ...  Publication_Day_Saturday  Publication_Day_Sunday  \
# 0  ...                      True                   False
# 1  ...                     False                    True
# 2  ...                     False                   False
# 3  ...                     False                    True
# 4  ...                     False                   False
#
#    Publication_Day_Thursday  Publication_Day_Tuesday  \
# 0                     False                    False
# 1                     False                    False
# 2                     False                    False
# 3                     False                    False
# 4                     False                    False
#
#    Publication_Day_Wednesday  Publication_Time_Afternoon  \
# 0                      False                       False
# 1                      False                       False
# 2                      False                       False
# 3                      False                       False
# 4                       True                       False
#
#    Publication_Time_Evening  Publication_Time_Morning  Publication_Time_Night  \
# 0                      True                     False                   False
# 1                     False                      True                   False
# 2                      True                     False                   False
# 3                     False                      True                   False
# 4                     False                      True                   False
#
#    Episode_Sentiment_mapped
# 0                         0
# 1                         0
# 2                         1
# 3                         1
# 4                         0
#
# [5 rows x 34 columns]

# %%
# drop the no longer needed 'Episode_Sentiment' column
test_encoded_df = test_encoded_df.drop(columns=['Episode_Sentiment'])
test_encoded_df.head()
# Out:
#        id  Episode_Length_minutes  Host_Popularity_percentage  \
# 0  750000                   78.96                       38.11
# 1  750001                   27.87                       71.29
# 2  750002                   69.10                       67.89
# 3  750003                  115.39                       23.40
# 4  750004                   72.32                       58.10
#
#    Guest_Popularity_percentage  Number_of_Ads  \
# 0                        53.33            1.0
# 1                          NaN            0.0
# 2                        97.51            0.0
# 3                        51.75            2.0
# 4                        11.30            2.0
#
#    Podcast_Name_clustered_Sports Weekly_cluster_1  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                            True
#
#    Podcast_Name_clustered_Tech Talks_cluster_0  \
# 0                                        False
# 1                                        False
# 2                                         True
# 3                                         True
# 4                                        False
#
#    Podcast_Name_clustered_Tech Trends_cluster_2  Episode_Title_binned_early  \
# 0                                          True                       False
# 1                                          True                        True
# 2                                         False                        True
# 3                                         False                       False
# 4                                         False                       False
#
#    Episode_Title_binned_late  ...  Publication_Day_Saturday  \
# 0                       True  ...                      True
# 1                      False  ...                     False
# 2                      False  ...                     False
# 3                       True  ...                     False
# 4                      False  ...                     False
#
#    Publication_Day_Sunday  Publication_Day_Thursday  Publication_Day_Tuesday  \
# 0                   False                     False                    False
# 1                    True                     False                    False
# 2                   False                     False                    False
# 3                    True                     False                    False
# 4                   False                     False                    False
#
#    Publication_Day_Wednesday  Publication_Time_Afternoon  \
# 0                      False                       False
# 1                      False                       False
# 2                      False                       False
# 3                      False                       False
# 4                       True                       False
#
#    Publication_Time_Evening  Publication_Time_Morning  Publication_Time_Night  \
# 0                      True                     False                   False
# 1                     False                      True                   False
# 2                      True                     False                   False
# 3                     False                      True                   False
# 4                     False                      True                   False
#
#    Episode_Sentiment_mapped
# 0                         0
# 1                         0
# 2                         1
# 3                         1
# 4                         0
#
# [5 rows x 33 columns]

# %%
# store the ID column and then drop
id_vals = test_encoded_df['id']
test_encoded_df = test_encoded_df.drop(columns=['id'])
test_encoded_df.head()
# Out:
#    Episode_Length_minutes  Host_Popularity_percentage  \
# 0                   78.96                       38.11
# 1                   27.87                       71.29
# 2                   69.10                       67.89
# 3                  115.39                       23.40
# 4                   72.32                       58.10
#
#    Guest_Popularity_percentage  Number_of_Ads  \
# 0                        53.33            1.0
# 1                          NaN            0.0
# 2                        97.51            0.0
# 3                        51.75            2.0
# 4                        11.30            2.0
#
#    Podcast_Name_clustered_Sports Weekly_cluster_1  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                            True
#
#    Podcast_Name_clustered_Tech Talks_cluster_0  \
# 0                                        False
# 1                                        False
# 2                                         True
# 3                                         True
# 4                                        False
#
#    Podcast_Name_clustered_Tech Trends_cluster_2  Episode_Title_binned_early  \
# 0                                          True                       False
# 1                                          True                        True
# 2                                         False                        True
# 3                                         False                       False
# 4                                         False                       False
#
#    Episode_Title_binned_late  Episode_Title_binned_mid  ...  \
# 0                       True                     False  ...
# 1                      False                     False  ...
# 2                      False                     False  ...
# 3                       True                     False  ...
# 4                      False                      True  ...
#
#    Publication_Day_Saturday  Publication_Day_Sunday  Publication_Day_Thursday  \
# 0                      True                   False                     False
# 1                     False                    True                     False
# 2                     False                   False                     False
# 3                     False                    True                     False
# 4                     False                   False                     False
#
#    Publication_Day_Tuesday  Publication_Day_Wednesday  \
# 0                    False                      False
# 1                    False                      False
# 2                    False                      False
# 3                    False                      False
# 4                    False                       True
#
#    Publication_Time_Afternoon  Publication_Time_Evening  \
# 0                       False                      True
# 1                       False                     False
# 2                       False                      True
# 3                       False                     False
# 4                       False                     False
#
#    Publication_Time_Morning  Publication_Time_Night  Episode_Sentiment_mapped
# 0                     False                   False                         0
# 1                      True                   False                         0
# 2                     False                   False                         1
# 3                      True                   False                         1
# 4                      True                   False                         0
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Pre-Processing

# %%
# examine null values across columns
test_encoded_df.isna().sum()
# Out:
# Episode_Length_minutes                            28736
# Host_Popularity_percentage                            0
# Guest_Popularity_percentage                       48832
# Number_of_Ads                                         0
# Podcast_Name_clustered_Sports Weekly_cluster_1        0
# Podcast_Name_clustered_Tech Talks_cluster_0           0
# Podcast_Name_clustered_Tech Trends_cluster_2          0
# Episode_Title_binned_early                            0
# Episode_Title_binned_late                             0
# Episode_Title_binned_mid                              0
# Genre_Business                                        0
# Genre_Comedy                                          0
# Genre_Education                                       0
# Genre_Health                                          0
# Genre_Lifestyle                                       0
# Genre_Music                                           0
# Genre_News                                            0
# Genre_Sports                                          0
# Genre_Technology                                      0
# Genre_True Crime                                      0
# Publication_Day_Friday                                0
# Publication_Day_Monday                                0
# Publication_Day_Saturday                              0
# Publication_Day_Sunday                                0
# Publication_Day_Thursday                              0
# Publication_Day_Tuesday                               0
# Publication_Day_Wednesday                             0
# Publication_Time_Afternoon                            0
# Publication_Time_Evening                              0
# Publication_Time_Morning                              0
# Publication_Time_Night                                0
# Episode_Sentiment_mapped                              0
# dtype: int64

# %%
# examine null values across columns
test_encoded_df.isna().sum() / len(test_encoded_df)
# Out:
# Episode_Length_minutes                            0.114944
# Host_Popularity_percentage                        0.000000
# Guest_Popularity_percentage                       0.195328
# Number_of_Ads                                     0.000000
# Podcast_Name_clustered_Sports Weekly_cluster_1    0.000000
# Podcast_Name_clustered_Tech Talks_cluster_0       0.000000
# Podcast_Name_clustered_Tech Trends_cluster_2      0.000000
# Episode_Title_binned_early                        0.000000
# Episode_Title_binned_late                         0.000000
# Episode_Title_binned_mid                          0.000000
# Genre_Business                                    0.000000
# Genre_Comedy                                      0.000000
# Genre_Education                                   0.000000
# Genre_Health                                      0.000000
# Genre_Lifestyle                                   0.000000
# Genre_Music                                       0.000000
# Genre_News                                        0.000000
# Genre_Sports                                      0.000000
# Genre_Technology                                  0.000000
# Genre_True Crime                                  0.000000
# Publication_Day_Friday                            0.000000
# Publication_Day_Monday                            0.000000
# Publication_Day_Saturday                          0.000000
# Publication_Day_Sunday                            0.000000
# Publication_Day_Thursday                          0.000000
# Publication_Day_Tuesday                           0.000000
# Publication_Day_Wednesday                         0.000000
# Publication_Time_Afternoon                        0.000000
# Publication_Time_Evening                          0.000000
# Publication_Time_Morning                          0.000000
# Publication_Time_Night                            0.000000
# Episode_Sentiment_mapped                          0.000000
# dtype: float64

# %%
# based on the data distribution the filling with mean strategy seems best for 'Episode_Length_minutes'
test_encoded_df['Episode_Length_minutes'] = test_encoded_df['Episode_Length_minutes'].fillna(test_encoded_df['Episode_Length_minutes'].mean(), inplace=False)

# %%
# examine null values across columns
test_encoded_df.isna().sum() / len(test_encoded_df)
# Out:
# Episode_Length_minutes                            0.000000
# Host_Popularity_percentage                        0.000000
# Guest_Popularity_percentage                       0.195328
# Number_of_Ads                                     0.000000
# Podcast_Name_clustered_Sports Weekly_cluster_1    0.000000
# Podcast_Name_clustered_Tech Talks_cluster_0       0.000000
# Podcast_Name_clustered_Tech Trends_cluster_2      0.000000
# Episode_Title_binned_early                        0.000000
# Episode_Title_binned_late                         0.000000
# Episode_Title_binned_mid                          0.000000
# Genre_Business                                    0.000000
# Genre_Comedy                                      0.000000
# Genre_Education                                   0.000000
# Genre_Health                                      0.000000
# Genre_Lifestyle                                   0.000000
# Genre_Music                                       0.000000
# Genre_News                                        0.000000
# Genre_Sports                                      0.000000
# Genre_Technology                                  0.000000
# Genre_True Crime                                  0.000000
# Publication_Day_Friday                            0.000000
# Publication_Day_Monday                            0.000000
# Publication_Day_Saturday                          0.000000
# Publication_Day_Sunday                            0.000000
# Publication_Day_Thursday                          0.000000
# Publication_Day_Tuesday                           0.000000
# Publication_Day_Wednesday                         0.000000
# Publication_Time_Afternoon                        0.000000
# Publication_Time_Evening                          0.000000
# Publication_Time_Morning                          0.000000
# Publication_Time_Night                            0.000000
# Episode_Sentiment_mapped                          0.000000
# dtype: float64

# %%
# based on the data distribution the filling with mean strategy seems best for 'Guest_Popularity_percentage'
test_encoded_df['Guest_Popularity_percentage'] = test_encoded_df['Guest_Popularity_percentage'].fillna(test_encoded_df['Guest_Popularity_percentage'].mean(), inplace=False)

# %%
# examine null values across columns
test_encoded_df.isna().sum() / len(test_encoded_df)
# Out:
# Episode_Length_minutes                            0.0
# Host_Popularity_percentage                        0.0
# Guest_Popularity_percentage                       0.0
# Number_of_Ads                                     0.0
# Podcast_Name_clustered_Sports Weekly_cluster_1    0.0
# Podcast_Name_clustered_Tech Talks_cluster_0       0.0
# Podcast_Name_clustered_Tech Trends_cluster_2      0.0
# Episode_Title_binned_early                        0.0
# Episode_Title_binned_late                         0.0
# Episode_Title_binned_mid                          0.0
# Genre_Business                                    0.0
# Genre_Comedy                                      0.0
# Genre_Education                                   0.0
# Genre_Health                                      0.0
# Genre_Lifestyle                                   0.0
# Genre_Music                                       0.0
# Genre_News                                        0.0
# Genre_Sports                                      0.0
# Genre_Technology                                  0.0
# Genre_True Crime                                  0.0
# Publication_Day_Friday                            0.0
# Publication_Day_Monday                            0.0
# Publication_Day_Saturday                          0.0
# Publication_Day_Sunday                            0.0
# Publication_Day_Thursday                          0.0
# Publication_Day_Tuesday                           0.0
# Publication_Day_Wednesday                         0.0
# Publication_Time_Afternoon                        0.0
# Publication_Time_Evening                          0.0
# Publication_Time_Morning                          0.0
# Publication_Time_Night                            0.0
# Episode_Sentiment_mapped                          0.0
# dtype: float64

# %%
# make sure all data types are numerical (or boolean)
test_encoded_df.dtypes
# Out:
# Episode_Length_minutes                            float64
# Host_Popularity_percentage                        float64
# Guest_Popularity_percentage                       float64
# Number_of_Ads                                     float64
# Podcast_Name_clustered_Sports Weekly_cluster_1       bool
# Podcast_Name_clustered_Tech Talks_cluster_0          bool
# Podcast_Name_clustered_Tech Trends_cluster_2         bool
# Episode_Title_binned_early                           bool
# Episode_Title_binned_late                            bool
# Episode_Title_binned_mid                             bool
# Genre_Business                                       bool
# Genre_Comedy                                         bool
# Genre_Education                                      bool
# Genre_Health                                         bool
# Genre_Lifestyle                                      bool
# Genre_Music                                          bool
# Genre_News                                           bool
# Genre_Sports                                         bool
# Genre_Technology                                     bool
# Genre_True Crime                                     bool
# Publication_Day_Friday                               bool
# Publication_Day_Monday                               bool
# Publication_Day_Saturday                             bool
# Publication_Day_Sunday                               bool
# Publication_Day_Thursday                             bool
# Publication_Day_Tuesday                              bool
# Publication_Day_Wednesday                            bool
# Publication_Time_Afternoon                           bool
# Publication_Time_Evening                             bool
# Publication_Time_Morning                             bool
# Publication_Time_Night                               bool
# Episode_Sentiment_mapped                            int64
# dtype: object

# %% [markdown]
# ### Model Inference

# %%
# make copy of test encoded and convert to X_pred
X_pred = test_encoded_df.copy()
X_pred.head()
# Out:
#    Episode_Length_minutes  Host_Popularity_percentage  \
# 0                   78.96                       38.11
# 1                   27.87                       71.29
# 2                   69.10                       67.89
# 3                  115.39                       23.40
# 4                   72.32                       58.10
#
#    Guest_Popularity_percentage  Number_of_Ads  \
# 0                    53.330000            1.0
# 1                    52.192796            0.0
# 2                    97.510000            0.0
# 3                    51.750000            2.0
# 4                    11.300000            2.0
#
#    Podcast_Name_clustered_Sports Weekly_cluster_1  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                            True
#
#    Podcast_Name_clustered_Tech Talks_cluster_0  \
# 0                                        False
# 1                                        False
# 2                                         True
# 3                                         True
# 4                                        False
#
#    Podcast_Name_clustered_Tech Trends_cluster_2  Episode_Title_binned_early  \
# 0                                          True                       False
# 1                                          True                        True
# 2                                         False                        True
# 3                                         False                       False
# 4                                         False                       False
#
#    Episode_Title_binned_late  Episode_Title_binned_mid  ...  \
# 0                       True                     False  ...
# 1                      False                     False  ...
# 2                      False                     False  ...
# 3                       True                     False  ...
# 4                      False                      True  ...
#
#    Publication_Day_Saturday  Publication_Day_Sunday  Publication_Day_Thursday  \
# 0                      True                   False                     False
# 1                     False                    True                     False
# 2                     False                   False                     False
# 3                     False                    True                     False
# 4                     False                   False                     False
#
#    Publication_Day_Tuesday  Publication_Day_Wednesday  \
# 0                    False                      False
# 1                    False                      False
# 2                    False                      False
# 3                    False                      False
# 4                    False                       True
#
#    Publication_Time_Afternoon  Publication_Time_Evening  \
# 0                       False                      True
# 1                       False                     False
# 2                       False                      True
# 3                       False                     False
# 4                       False                     False
#
#    Publication_Time_Morning  Publication_Time_Night  Episode_Sentiment_mapped
# 0                     False                   False                         0
# 1                      True                   False                         0
# 2                     False                   False                         1
# 3                      True                   False                         1
# 4                      True                   False                         0
#
# [5 rows x 32 columns]

# %%
### REFACTOR TO GENERALIZE
# hard coded load of the random forest model since it had the lowest RMSE
best_model = joblib.load(saved_paths['random_forest'])

# %%
# make predictions
y_pred = best_model.predict(X_pred)

# %% [markdown]
# ### Construct Submission

# %%
# build submission dataframe for Kaggle submission
submit_df = pd.DataFrame()
submit_df['id'] = list(id_vals)
submit_df['Listening_Time_minutes'] = list(y_pred)
submit_df.head()
# Out:
#        id  Listening_Time_minutes
# 0  750000               55.843055
# 1  750001               23.471401
# 2  750002               48.588094
# 3  750003               76.435868
# 4  750004               46.301973

# %%
# make the id column the index
submit_df = submit_df.set_index('id')
submit_df.head()
# Out:
#         Listening_Time_minutes
# id
# 750000               55.843055
# 750001               23.471401
# 750002               48.588094
# 750003               76.435868
# 750004               46.301973

# %%
# output the dataframe to file to be uploaded to Kaggle
submit_df.to_csv('data/submissions/submission_1.csv')
